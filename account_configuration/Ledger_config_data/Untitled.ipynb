# %%
import pandas as pd

# Load ledger
ledger_df = pd.read_excel("Ledger_Library.xlsx")

# Show existing combinations
print("💼 Existing Ledger Accounts:\n")
for idx, row in ledger_df.iterrows():
    print(f"{idx}. {row['C1']} > {row['C2']} > {row['C3']}")

choice = input("\n📌 Select a number from above or type 'new' to enter manually: ")

if choice.lower() == 'new':
    C1 = input("Enter Main Account Type (C1): ")
    C2 = input("Enter Sub Account Type (C2): ")
    C3 = input("Enter Account Name (C3): ")
    C4 = input("Enter Account Code (C4): ")
    C5 = input("Enter Remarks/Info (C5): ")
else:
    idx = int(choice)
    C1 = ledger_df.loc[idx, 'C1']
    C2 = ledger_df.loc[idx, 'C2']
    C3 = ledger_df.loc[idx, 'C3']
    print(f"Selected: {C1} > {C2} > {C3}")
    C4 = input("Enter Account Code (C4): ")
    C5 = input("Enter Remarks/Info (C5): ")

print("\n✅ Final Selection:")
print(f"C1: {C1}\nC2: {C2}\nC3: {C3}\nC4: {C4}\nC5: {C5}")
# Out:
# 💼 Existing Ledger Accounts:
#
# 0. ASSET > CurrentAsset > cash account
# 1. ASSET > CurrentAsset > bank a/c
# 2. ASSET > CurrentAsset > cashequivalents
# 3. ASSET > CurrentAsset > shorttermdeposits
# 4. ASSET > CurrentAsset > accountsreceivables
# 5. ASSET > CurrentAsset > inventory
# 6. ASSET > CurrentAsset > marketablesecurities
# 7. ASSET > CurrentAsset > officesupplies
# 8. ASSET > CurrentAsset > prepaidexpenses
# 9. ASSET > FixedAsset > land
# 10. ASSET > FixedAsset > building
# 11. ASSET > FixedAsset > machinery
# 12. ASSET > FixedAsset > equipment
# 13. ASSET > FixedAsset > patents
# 14. ASSET > FixedAsset > trademarks
# 15. ASSET > FixedAsset > goodwill
# 16. ASSET > FixedAsset > brand
# 17. ASSET > FixedAsset > copyrights
# 18. ASSET > FixedAsset > trade secrets
# 19. ASSET > FixedAsset > licenses and permits
# 20. ASSET > FixedAsset > corporate intellectual property
# 21. LIABILITY > Current_Liability > accounts payable
# ...
